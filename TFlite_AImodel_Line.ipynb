# %%
# Define paths to model files
import os
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL_TF = MODELS_DIR + 'model'
MODEL_NO_QUANT_TFLITE = MODELS_DIR + 'model_no_quant.tflite'
MODEL_TFLITE = MODELS_DIR + 'model.tflite'
MODEL_TFLITE_MICRO = MODELS_DIR + 'model.cc'

# %%
! pip install tensorflow==2.4.0
# Out:
# Collecting tensorflow==2.4.0
#   Downloading tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl (394.7 MB)
#      |████████████████████████████████| 394.7 MB 17 kB/s
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (0.2.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (3.3.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.1.2)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0rc0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 70.8 MB/s
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 46.8 MB/s
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (3.17.3)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.15.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (2.8.0)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.1.0)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 61.4 MB/s
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 43.6 MB/s
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 39.1 MB/s
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (0.37.1)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0) (3.2.0)
# Building wheels for collected packages: wrapt
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68717 sha256=73c2830d33cf862e269e94863720c23f12c549be225a54bcde7cae96834c3492
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# Installing collected packages: typing-extensions, numpy, grpcio, absl-py, wrapt, tensorflow-estimator, h5py, gast, flatbuffers, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.46.1
#     Uninstalling grpcio-1.46.1:
#       Successfully uninstalled grpcio-1.46.1
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.0.0
#     Uninstalling absl-py-1.0.0:
#       Successfully uninstalled absl-py-1.0.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0+zzzcolab20220506162203
#     Uninstalling tensorflow-2.8.0+zzzcolab20220506162203:
#       Successfully uninstalled tensorflow-2.8.0+zzzcolab20220506162203
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed absl-py-0.15.0 flatbuffers-1.12 gast-0.3.3 grpcio-1.32.0 h5py-2.10.0 numpy-1.19.5 tensorflow-2.4.0 tensorflow-estimator-2.4.0 typing-extensions-3.7.4.3 wrapt-1.12.1

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf

# Keras is TensorFlow's high-level API for deep learning
from tensorflow import keras
# Numpy is a math library
import numpy as np
# Pandas is a data manipulation library 
import pandas as pd
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# Math is Python's math library
import math

# Set seed for experiment reproducibility
seed = 1
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# Number of sample datapoints
SAMPLES = 1000

# Generate a uniformly distributed set of random numbers in the range from
# 0 to 1000, which covers a complete line
x_values = np.random.uniform(low=0, high=100, size=SAMPLES).astype(np.float32)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

# create line-function to be predicted
#def y_values(x):
#  return (10*x+5)/2

# Calculate the corresponding line values
#y_values = np.frompyfunc(y_values, 1,1)
y_values = ((10 * x_values) + 5).astype(np.float32)

# Plot our data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %%
# Add a small random number to each y value
y_values += 0.1 * np.random.randn(*y_values.shape)
print(y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()
# Out:
# (1000,)

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %%
# RE-Design model to improve the accuracy
model = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model.add(keras.layers.Dense(16, activation='relu', input_shape=(1,)))

# The new second and third layer will help the network learn more complex representations
model.add(keras.layers.Dense(16, activation='relu'))

# The new second and third layer will help the network learn more complex representations
model.add(keras.layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model.add(keras.layers.Dense(1))

# Compile the model using the standard 'adam' optimizer and the mean squared error or 'mse' loss function for regression.
model.compile(optimizer='adam', loss="mse", metrics=["mae"])

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=500, batch_size=64,
                    validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/500
# 10/10 [==============================] - 1s 18ms/step - loss: 343476.9688 - mae: 508.5686 - val_loss: 354508.2500 - val_mae: 517.2452
# Epoch 2/500
# 10/10 [==============================] - 0s 5ms/step - loss: 339770.6250 - mae: 505.8073 - val_loss: 351286.4375 - val_mae: 514.8907
# Epoch 3/500
# 10/10 [==============================] - 0s 6ms/step - loss: 337026.5625 - mae: 503.7694 - val_loss: 348462.0000 - val_mae: 512.8125
# Epoch 4/500
# 10/10 [==============================] - 0s 5ms/step - loss: 333353.9062 - mae: 500.9954 - val_loss: 343681.6875 - val_mae: 509.2891
# Epoch 5/500
# 10/10 [==============================] - 0s 6ms/step - loss: 329102.2812 - mae: 497.8196 - val_loss: 339528.2500 - val_mae: 506.2028
# Epoch 6/500
# 10/10 [==============================] - 0s 5ms/step - loss: 324934.8750 - mae: 494.6572 - val_loss: 334512.9062 - val_mae: 502.4415
# Epoch 7/500
# 10/10 [==============================] - 0s 6ms/step - loss: 318937.0312 - mae: 490.0577 - val_loss: 326732.3438 - val_mae: 496.5616
# Epoch 8/500
# 10/10 [==============================] - 0s 5ms/step - loss: 310909.0938 - mae: 483.8496 - val_loss: 317468.5312 - val_mae: 489.4682
# Epoch 9/500
# 10/10 [==============================] - 0s 7ms/step - loss: 301069.3438 - mae: 476.1300 - val_loss: 305874.6250 - val_mae: 480.4419
# Epoch 10/500
# 10/10 [==============================] - 0s 4ms/step - loss: 289031.8438 - mae: 466.4373 - val_loss: 291773.9688 - val_mae: 469.2311
# Epoch 11/500
# 10/10 [==============================] - 0s 5ms/step - loss: 274505.9062 - mae: 454.5131 - val_loss: 275172.5625 - val_mae: 455.6791
# Epoch 12/500
# 10/10 [==============================] - 0s 6ms/step - loss: 257263.1719 - mae: 440.0603 - val_loss: 255686.5469 - val_mae: 439.2388
# Epoch 13/500
# 10/10 [==============================] - 0s 5ms/step - loss: 237205.5938 - mae: 422.4709 - val_loss: 233063.9375 - val_mae: 419.3418
# Epoch 14/500
# 10/10 [==============================] - 0s 6ms/step - loss: 213825.0781 - mae: 401.1375 - val_loss: 206134.8125 - val_mae: 394.3407
# Epoch 15/500
# 10/10 [==============================] - 0s 6ms/step - loss: 186167.2344 - mae: 374.1716 - val_loss: 175475.2812 - val_mae: 363.8218
# Epoch 16/500
# 10/10 [==============================] - 0s 6ms/step - loss: 155703.7500 - mae: 342.4342 - val_loss: 143092.4531 - val_mae: 328.5060
# Epoch 17/500
# 10/10 [==============================] - 0s 6ms/step - loss: 124493.2031 - mae: 305.7115 - val_loss: 109973.0312 - val_mae: 287.9436
# Epoch 18/500
# 10/10 [==============================] - 0s 5ms/step - loss: 93106.9688 - mae: 264.2046 - val_loss: 78540.7188 - val_mae: 243.2761
# Epoch 19/500
# 10/10 [==============================] - 0s 5ms/step - loss: 64068.6211 - mae: 218.9148 - val_loss: 50397.0547 - val_mae: 194.7959
# Epoch 20/500
# 10/10 [==============================] - 0s 6ms/step - loss: 38834.4727 - mae: 170.3371 - val_loss: 27887.5859 - val_mae: 144.7993
# Epoch 21/500
# 10/10 [==============================] - 0s 7ms/step - loss: 19785.0215 - mae: 121.2421 - val_loss: 12438.2246 - val_mae: 96.5641
# Epoch 22/500
# 10/10 [==============================] - 0s 6ms/step - loss: 7974.8652 - mae: 76.3992 - val_loss: 3976.4104 - val_mae: 54.4163
# Epoch 23/500
# 10/10 [==============================] - 0s 4ms/step - loss: 2219.1611 - mae: 39.2447 - val_loss: 662.1258 - val_mae: 21.9555
# Epoch 24/500
# 10/10 [==============================] - 0s 5ms/step - loss: 262.4489 - mae: 12.6667 - val_loss: 14.6272 - val_mae: 3.0877
# Epoch 25/500
# 10/10 [==============================] - 0s 4ms/step - loss: 9.4616 - mae: 2.5550 - val_loss: 31.8421 - val_mae: 5.2654
# Epoch 26/500
# 10/10 [==============================] - 0s 6ms/step - loss: 42.1551 - mae: 5.9960 - val_loss: 46.1465 - val_mae: 6.2748
# Epoch 27/500
# 10/10 [==============================] - 0s 4ms/step - loss: 35.4473 - mae: 5.5107 - val_loss: 21.4826 - val_mae: 4.3763
# Epoch 28/500
# 10/10 [==============================] - 0s 5ms/step - loss: 12.6772 - mae: 3.3541 - val_loss: 4.6233 - val_mae: 2.1333
# Epoch 29/500
# 10/10 [==============================] - 0s 5ms/step - loss: 2.2908 - mae: 1.4264 - val_loss: 0.7772 - val_mae: 0.7285
# Epoch 30/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7531 - mae: 0.7323 - val_loss: 0.9147 - val_mae: 0.8205
# Epoch 31/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9365 - mae: 0.8367 - val_loss: 0.9964 - val_mae: 0.8543
# Epoch 32/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8935 - mae: 0.8163 - val_loss: 0.8372 - val_mae: 0.7878
# Epoch 33/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7607 - mae: 0.7484 - val_loss: 0.7284 - val_mae: 0.7298
# Epoch 34/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7043 - mae: 0.7071 - val_loss: 0.7013 - val_mae: 0.7067
# Epoch 35/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6974 - mae: 0.6966 - val_loss: 0.6986 - val_mae: 0.7033
# Epoch 36/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6974 - mae: 0.6946 - val_loss: 0.6974 - val_mae: 0.7025
# Epoch 37/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6956 - mae: 0.6941 - val_loss: 0.6958 - val_mae: 0.7024
# Epoch 38/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6932 - mae: 0.6946 - val_loss: 0.6951 - val_mae: 0.7030
# Epoch 39/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6914 - mae: 0.6952 - val_loss: 0.6947 - val_mae: 0.7035
# Epoch 40/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6901 - mae: 0.6955 - val_loss: 0.6935 - val_mae: 0.7030
# Epoch 41/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6887 - mae: 0.6948 - val_loss: 0.6920 - val_mae: 0.7022
# Epoch 42/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6871 - mae: 0.6935 - val_loss: 0.6899 - val_mae: 0.7006
# Epoch 43/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6856 - mae: 0.6922 - val_loss: 0.6880 - val_mae: 0.6994
# Epoch 44/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6842 - mae: 0.6913 - val_loss: 0.6866 - val_mae: 0.6986
# Epoch 45/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6829 - mae: 0.6901 - val_loss: 0.6847 - val_mae: 0.6973
# Epoch 46/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6813 - mae: 0.6890 - val_loss: 0.6833 - val_mae: 0.6967
# Epoch 47/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6797 - mae: 0.6884 - val_loss: 0.6820 - val_mae: 0.6962
# Epoch 48/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6782 - mae: 0.6885 - val_loss: 0.6808 - val_mae: 0.6960
# Epoch 49/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6765 - mae: 0.6878 - val_loss: 0.6796 - val_mae: 0.6955
# Epoch 50/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6753 - mae: 0.6881 - val_loss: 0.6787 - val_mae: 0.6956
# Epoch 51/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6735 - mae: 0.6870 - val_loss: 0.6764 - val_mae: 0.6940
# Epoch 52/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6717 - mae: 0.6857 - val_loss: 0.6746 - val_mae: 0.6928
# Epoch 53/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6703 - mae: 0.6844 - val_loss: 0.6722 - val_mae: 0.6911
# Epoch 54/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6686 - mae: 0.6834 - val_loss: 0.6708 - val_mae: 0.6905
# Epoch 55/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6669 - mae: 0.6822 - val_loss: 0.6686 - val_mae: 0.6890
# Epoch 56/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6652 - mae: 0.6807 - val_loss: 0.6672 - val_mae: 0.6884
# Epoch 57/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6633 - mae: 0.6808 - val_loss: 0.6663 - val_mae: 0.6886
# Epoch 58/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6618 - mae: 0.6806 - val_loss: 0.6645 - val_mae: 0.6876
# Epoch 59/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6600 - mae: 0.6796 - val_loss: 0.6626 - val_mae: 0.6865
# Epoch 60/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6582 - mae: 0.6783 - val_loss: 0.6606 - val_mae: 0.6852
# Epoch 61/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6565 - mae: 0.6773 - val_loss: 0.6590 - val_mae: 0.6845
# Epoch 62/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6546 - mae: 0.6763 - val_loss: 0.6570 - val_mae: 0.6833
# Epoch 63/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6529 - mae: 0.6752 - val_loss: 0.6552 - val_mae: 0.6824
# Epoch 64/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6511 - mae: 0.6746 - val_loss: 0.6535 - val_mae: 0.6817
# Epoch 65/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6493 - mae: 0.6740 - val_loss: 0.6521 - val_mae: 0.6812
# Epoch 66/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6474 - mae: 0.6733 - val_loss: 0.6502 - val_mae: 0.6802
# Epoch 67/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6456 - mae: 0.6719 - val_loss: 0.6479 - val_mae: 0.6786
# Epoch 68/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6438 - mae: 0.6708 - val_loss: 0.6463 - val_mae: 0.6779
# Epoch 69/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6419 - mae: 0.6703 - val_loss: 0.6445 - val_mae: 0.6771
# Epoch 70/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6399 - mae: 0.6686 - val_loss: 0.6420 - val_mae: 0.6753
# Epoch 71/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6379 - mae: 0.6674 - val_loss: 0.6405 - val_mae: 0.6748
# Epoch 72/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6360 - mae: 0.6669 - val_loss: 0.6387 - val_mae: 0.6740
# Epoch 73/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6341 - mae: 0.6660 - val_loss: 0.6367 - val_mae: 0.6728
# Epoch 74/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6323 - mae: 0.6653 - val_loss: 0.6350 - val_mae: 0.6721
# Epoch 75/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6303 - mae: 0.6639 - val_loss: 0.6326 - val_mae: 0.6705
# Epoch 76/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6283 - mae: 0.6623 - val_loss: 0.6303 - val_mae: 0.6689
# Epoch 77/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6263 - mae: 0.6610 - val_loss: 0.6284 - val_mae: 0.6680
# Epoch 78/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6244 - mae: 0.6603 - val_loss: 0.6265 - val_mae: 0.6671
# Epoch 79/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6225 - mae: 0.6589 - val_loss: 0.6242 - val_mae: 0.6655
# Epoch 80/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6205 - mae: 0.6581 - val_loss: 0.6226 - val_mae: 0.6652
# Epoch 81/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6183 - mae: 0.6575 - val_loss: 0.6208 - val_mae: 0.6643
# Epoch 82/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6163 - mae: 0.6563 - val_loss: 0.6185 - val_mae: 0.6628
# Epoch 83/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6145 - mae: 0.6556 - val_loss: 0.6168 - val_mae: 0.6622
# Epoch 84/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6122 - mae: 0.6544 - val_loss: 0.6145 - val_mae: 0.6607
# Epoch 85/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6102 - mae: 0.6527 - val_loss: 0.6121 - val_mae: 0.6592
# Epoch 86/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6080 - mae: 0.6516 - val_loss: 0.6103 - val_mae: 0.6584
# Epoch 87/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6060 - mae: 0.6512 - val_loss: 0.6085 - val_mae: 0.6578
# Epoch 88/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6040 - mae: 0.6502 - val_loss: 0.6066 - val_mae: 0.6568
# Epoch 89/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6018 - mae: 0.6492 - val_loss: 0.6042 - val_mae: 0.6553
# Epoch 90/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5995 - mae: 0.6473 - val_loss: 0.6015 - val_mae: 0.6534
# Epoch 91/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5975 - mae: 0.6458 - val_loss: 0.5994 - val_mae: 0.6523
# Epoch 92/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5953 - mae: 0.6446 - val_loss: 0.5974 - val_mae: 0.6513
# Epoch 93/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5931 - mae: 0.6438 - val_loss: 0.5954 - val_mae: 0.6503
# Epoch 94/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5910 - mae: 0.6428 - val_loss: 0.5933 - val_mae: 0.6492
# Epoch 95/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5891 - mae: 0.6413 - val_loss: 0.5907 - val_mae: 0.6473
# Epoch 96/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5866 - mae: 0.6400 - val_loss: 0.5889 - val_mae: 0.6468
# Epoch 97/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5844 - mae: 0.6394 - val_loss: 0.5870 - val_mae: 0.6459
# Epoch 98/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5822 - mae: 0.6382 - val_loss: 0.5845 - val_mae: 0.6443
# Epoch 99/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5800 - mae: 0.6371 - val_loss: 0.5828 - val_mae: 0.6437
# Epoch 100/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5779 - mae: 0.6359 - val_loss: 0.5800 - val_mae: 0.6417
# Epoch 101/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5761 - mae: 0.6354 - val_loss: 0.5785 - val_mae: 0.6414
# Epoch 102/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5733 - mae: 0.6332 - val_loss: 0.5752 - val_mae: 0.6386
# Epoch 103/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5712 - mae: 0.6312 - val_loss: 0.5730 - val_mae: 0.6374
# Epoch 104/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5690 - mae: 0.6303 - val_loss: 0.5709 - val_mae: 0.6365
# Epoch 105/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5667 - mae: 0.6288 - val_loss: 0.5686 - val_mae: 0.6350
# Epoch 106/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5646 - mae: 0.6277 - val_loss: 0.5665 - val_mae: 0.6341
# Epoch 107/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5622 - mae: 0.6273 - val_loss: 0.5646 - val_mae: 0.6334
# Epoch 108/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5599 - mae: 0.6256 - val_loss: 0.5617 - val_mae: 0.6312
# Epoch 109/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5575 - mae: 0.6246 - val_loss: 0.5600 - val_mae: 0.6307
# Epoch 110/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5553 - mae: 0.6229 - val_loss: 0.5569 - val_mae: 0.6282
# Epoch 111/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5531 - mae: 0.6218 - val_loss: 0.5550 - val_mae: 0.6277
# Epoch 112/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5505 - mae: 0.6200 - val_loss: 0.5523 - val_mae: 0.6257
# Epoch 113/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5482 - mae: 0.6186 - val_loss: 0.5501 - val_mae: 0.6246
# Epoch 114/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5458 - mae: 0.6172 - val_loss: 0.5477 - val_mae: 0.6230
# Epoch 115/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5436 - mae: 0.6162 - val_loss: 0.5456 - val_mae: 0.6221
# Epoch 116/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5412 - mae: 0.6153 - val_loss: 0.5434 - val_mae: 0.6210
# Epoch 117/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5390 - mae: 0.6133 - val_loss: 0.5407 - val_mae: 0.6191
# Epoch 118/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5364 - mae: 0.6128 - val_loss: 0.5394 - val_mae: 0.6192
# Epoch 119/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5343 - mae: 0.6122 - val_loss: 0.5367 - val_mae: 0.6174
# Epoch 120/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5319 - mae: 0.6106 - val_loss: 0.5342 - val_mae: 0.6159
# Epoch 121/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5295 - mae: 0.6082 - val_loss: 0.5313 - val_mae: 0.6136
# Epoch 122/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5271 - mae: 0.6070 - val_loss: 0.5294 - val_mae: 0.6129
# Epoch 123/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5248 - mae: 0.6063 - val_loss: 0.5271 - val_mae: 0.6117
# Epoch 124/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5224 - mae: 0.6042 - val_loss: 0.5242 - val_mae: 0.6094
# Epoch 125/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5201 - mae: 0.6031 - val_loss: 0.5224 - val_mae: 0.6089
# Epoch 126/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5177 - mae: 0.6026 - val_loss: 0.5204 - val_mae: 0.6080
# Epoch 127/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5156 - mae: 0.6005 - val_loss: 0.5169 - val_mae: 0.6050
# Epoch 128/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5128 - mae: 0.5981 - val_loss: 0.5145 - val_mae: 0.6035
# Epoch 129/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5105 - mae: 0.5966 - val_loss: 0.5122 - val_mae: 0.6024
# Epoch 130/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5082 - mae: 0.5967 - val_loss: 0.5107 - val_mae: 0.6023
# Epoch 131/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5059 - mae: 0.5950 - val_loss: 0.5073 - val_mae: 0.5994
# Epoch 132/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5029 - mae: 0.5925 - val_loss: 0.5053 - val_mae: 0.5986
# Epoch 133/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5009 - mae: 0.5929 - val_loss: 0.5037 - val_mae: 0.5984
# Epoch 134/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4983 - mae: 0.5913 - val_loss: 0.5007 - val_mae: 0.5962
# Epoch 135/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4958 - mae: 0.5892 - val_loss: 0.4976 - val_mae: 0.5938
# Epoch 136/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4933 - mae: 0.5868 - val_loss: 0.4951 - val_mae: 0.5922
# Epoch 137/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4908 - mae: 0.5856 - val_loss: 0.4927 - val_mae: 0.5908
# Epoch 138/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4885 - mae: 0.5850 - val_loss: 0.4908 - val_mae: 0.5902
# Epoch 139/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4865 - mae: 0.5828 - val_loss: 0.4872 - val_mae: 0.5866
# Epoch 140/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4836 - mae: 0.5804 - val_loss: 0.4854 - val_mae: 0.5864
# Epoch 141/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4810 - mae: 0.5804 - val_loss: 0.4836 - val_mae: 0.5858
# Epoch 142/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4785 - mae: 0.5793 - val_loss: 0.4807 - val_mae: 0.5839
# Epoch 143/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4761 - mae: 0.5768 - val_loss: 0.4775 - val_mae: 0.5810
# Epoch 144/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4735 - mae: 0.5748 - val_loss: 0.4755 - val_mae: 0.5803
# Epoch 145/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4712 - mae: 0.5746 - val_loss: 0.4732 - val_mae: 0.5792
# Epoch 146/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4684 - mae: 0.5727 - val_loss: 0.4704 - val_mae: 0.5773
# Epoch 147/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4662 - mae: 0.5716 - val_loss: 0.4682 - val_mae: 0.5761
# Epoch 148/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4632 - mae: 0.5691 - val_loss: 0.4649 - val_mae: 0.5733
# Epoch 149/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4611 - mae: 0.5679 - val_loss: 0.4630 - val_mae: 0.5728
# Epoch 150/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4583 - mae: 0.5667 - val_loss: 0.4603 - val_mae: 0.5710
# Epoch 151/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4560 - mae: 0.5652 - val_loss: 0.4579 - val_mae: 0.5696
# Epoch 152/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4531 - mae: 0.5628 - val_loss: 0.4548 - val_mae: 0.5670
# Epoch 153/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4508 - mae: 0.5607 - val_loss: 0.4525 - val_mae: 0.5656
# Epoch 154/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4483 - mae: 0.5601 - val_loss: 0.4504 - val_mae: 0.5648
# Epoch 155/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4457 - mae: 0.5583 - val_loss: 0.4475 - val_mae: 0.5626
# Epoch 156/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4434 - mae: 0.5558 - val_loss: 0.4446 - val_mae: 0.5599
# Epoch 157/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4407 - mae: 0.5546 - val_loss: 0.4428 - val_mae: 0.5600
# Epoch 158/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4383 - mae: 0.5538 - val_loss: 0.4400 - val_mae: 0.5579
# Epoch 159/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4357 - mae: 0.5526 - val_loss: 0.4381 - val_mae: 0.5573
# Epoch 160/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4333 - mae: 0.5505 - val_loss: 0.4347 - val_mae: 0.5542
# Epoch 161/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4308 - mae: 0.5494 - val_loss: 0.4333 - val_mae: 0.5543
# Epoch 162/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4281 - mae: 0.5478 - val_loss: 0.4300 - val_mae: 0.5514
# Epoch 163/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4257 - mae: 0.5452 - val_loss: 0.4271 - val_mae: 0.5490
# Epoch 164/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4233 - mae: 0.5440 - val_loss: 0.4253 - val_mae: 0.5486
# Epoch 165/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4207 - mae: 0.5424 - val_loss: 0.4224 - val_mae: 0.5464
# Epoch 166/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4184 - mae: 0.5420 - val_loss: 0.4206 - val_mae: 0.5459
# Epoch 167/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4156 - mae: 0.5397 - val_loss: 0.4172 - val_mae: 0.5429
# Epoch 168/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4129 - mae: 0.5372 - val_loss: 0.4148 - val_mae: 0.5415
# Epoch 169/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4104 - mae: 0.5355 - val_loss: 0.4122 - val_mae: 0.5396
# Epoch 170/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4082 - mae: 0.5335 - val_loss: 0.4097 - val_mae: 0.5379
# Epoch 171/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4053 - mae: 0.5325 - val_loss: 0.4081 - val_mae: 0.5377
# Epoch 172/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4029 - mae: 0.5316 - val_loss: 0.4051 - val_mae: 0.5354
# Epoch 173/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4004 - mae: 0.5291 - val_loss: 0.4020 - val_mae: 0.5325
# Epoch 174/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3978 - mae: 0.5273 - val_loss: 0.3997 - val_mae: 0.5314
# Epoch 175/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3953 - mae: 0.5261 - val_loss: 0.3976 - val_mae: 0.5303
# Epoch 176/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3929 - mae: 0.5239 - val_loss: 0.3945 - val_mae: 0.5275
# Epoch 177/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3904 - mae: 0.5224 - val_loss: 0.3925 - val_mae: 0.5268
# Epoch 178/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3880 - mae: 0.5218 - val_loss: 0.3903 - val_mae: 0.5256
# Epoch 179/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3854 - mae: 0.5200 - val_loss: 0.3874 - val_mae: 0.5233
# Epoch 180/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3830 - mae: 0.5173 - val_loss: 0.3845 - val_mae: 0.5207
# Epoch 181/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3803 - mae: 0.5154 - val_loss: 0.3821 - val_mae: 0.5192
# Epoch 182/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3781 - mae: 0.5149 - val_loss: 0.3803 - val_mae: 0.5187
# Epoch 183/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3752 - mae: 0.5122 - val_loss: 0.3767 - val_mae: 0.5149
# Epoch 184/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3728 - mae: 0.5099 - val_loss: 0.3743 - val_mae: 0.5135
# Epoch 185/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3704 - mae: 0.5090 - val_loss: 0.3722 - val_mae: 0.5126
# Epoch 186/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3677 - mae: 0.5072 - val_loss: 0.3698 - val_mae: 0.5111
# Epoch 187/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3654 - mae: 0.5065 - val_loss: 0.3674 - val_mae: 0.5095
# Epoch 188/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3637 - mae: 0.5033 - val_loss: 0.3641 - val_mae: 0.5053
# Epoch 189/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3602 - mae: 0.5008 - val_loss: 0.3621 - val_mae: 0.5053
# Epoch 190/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3580 - mae: 0.5015 - val_loss: 0.3611 - val_mae: 0.5059
# Epoch 191/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3554 - mae: 0.4996 - val_loss: 0.3571 - val_mae: 0.5018
# Epoch 192/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3527 - mae: 0.4962 - val_loss: 0.3543 - val_mae: 0.4992
# Epoch 193/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3504 - mae: 0.4942 - val_loss: 0.3520 - val_mae: 0.4977
# Epoch 194/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3484 - mae: 0.4944 - val_loss: 0.3503 - val_mae: 0.4976
# Epoch 195/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3454 - mae: 0.4922 - val_loss: 0.3473 - val_mae: 0.4948
# Epoch 196/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3432 - mae: 0.4890 - val_loss: 0.3444 - val_mae: 0.4917
# Epoch 197/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3405 - mae: 0.4878 - val_loss: 0.3425 - val_mae: 0.4913
# Epoch 198/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3383 - mae: 0.4870 - val_loss: 0.3403 - val_mae: 0.4900
# Epoch 199/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3356 - mae: 0.4842 - val_loss: 0.3372 - val_mae: 0.4869
# Epoch 200/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3333 - mae: 0.4828 - val_loss: 0.3355 - val_mae: 0.4866
# Epoch 201/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3314 - mae: 0.4830 - val_loss: 0.3329 - val_mae: 0.4845
# Epoch 202/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3283 - mae: 0.4791 - val_loss: 0.3300 - val_mae: 0.4818
# Epoch 203/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3258 - mae: 0.4772 - val_loss: 0.3277 - val_mae: 0.4803
# Epoch 204/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3234 - mae: 0.4754 - val_loss: 0.3251 - val_mae: 0.4781
# Epoch 205/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3213 - mae: 0.4746 - val_loss: 0.3231 - val_mae: 0.4773
# Epoch 206/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3189 - mae: 0.4718 - val_loss: 0.3200 - val_mae: 0.4736
# Epoch 207/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3164 - mae: 0.4708 - val_loss: 0.3185 - val_mae: 0.4741
# Epoch 208/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3138 - mae: 0.4690 - val_loss: 0.3155 - val_mae: 0.4709
# Epoch 209/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3113 - mae: 0.4664 - val_loss: 0.3130 - val_mae: 0.4689
# Epoch 210/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3093 - mae: 0.4660 - val_loss: 0.3111 - val_mae: 0.4684
# Epoch 211/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3064 - mae: 0.4627 - val_loss: 0.3078 - val_mae: 0.4641
# Epoch 212/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3043 - mae: 0.4612 - val_loss: 0.3060 - val_mae: 0.4640
# Epoch 213/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3016 - mae: 0.4594 - val_loss: 0.3036 - val_mae: 0.4620
# Epoch 214/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2993 - mae: 0.4572 - val_loss: 0.3009 - val_mae: 0.4595
# Epoch 215/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2969 - mae: 0.4552 - val_loss: 0.2987 - val_mae: 0.4581
# Epoch 216/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2947 - mae: 0.4547 - val_loss: 0.2968 - val_mae: 0.4571
# Epoch 217/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2920 - mae: 0.4520 - val_loss: 0.2938 - val_mae: 0.4537
# Epoch 218/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2904 - mae: 0.4492 - val_loss: 0.2913 - val_mae: 0.4509
# Epoch 219/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2877 - mae: 0.4475 - val_loss: 0.2894 - val_mae: 0.4508
# Epoch 220/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2858 - mae: 0.4484 - val_loss: 0.2879 - val_mae: 0.4505
# Epoch 221/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2829 - mae: 0.4442 - val_loss: 0.2844 - val_mae: 0.4455
# Epoch 222/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2811 - mae: 0.4430 - val_loss: 0.2825 - val_mae: 0.4454
# Epoch 223/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2784 - mae: 0.4417 - val_loss: 0.2799 - val_mae: 0.4429
# Epoch 224/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2762 - mae: 0.4385 - val_loss: 0.2773 - val_mae: 0.4399
# Epoch 225/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2738 - mae: 0.4364 - val_loss: 0.2751 - val_mae: 0.4387
# Epoch 226/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2721 - mae: 0.4367 - val_loss: 0.2738 - val_mae: 0.4390
# Epoch 227/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2690 - mae: 0.4338 - val_loss: 0.2706 - val_mae: 0.4349
# Epoch 228/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2674 - mae: 0.4312 - val_loss: 0.2682 - val_mae: 0.4323
# Epoch 229/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2645 - mae: 0.4291 - val_loss: 0.2667 - val_mae: 0.4330
# Epoch 230/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2624 - mae: 0.4289 - val_loss: 0.2642 - val_mae: 0.4306
# Epoch 231/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2602 - mae: 0.4275 - val_loss: 0.2620 - val_mae: 0.4288
# Epoch 232/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2577 - mae: 0.4240 - val_loss: 0.2591 - val_mae: 0.4249
# Epoch 233/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2555 - mae: 0.4217 - val_loss: 0.2571 - val_mae: 0.4242
# Epoch 234/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2537 - mae: 0.4225 - val_loss: 0.2557 - val_mae: 0.4240
# Epoch 235/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2510 - mae: 0.4188 - val_loss: 0.2524 - val_mae: 0.4193
# Epoch 236/500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.2488 - mae: 0.4167 - val_loss: 0.2505 - val_mae: 0.4188
# Epoch 237/500
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2465 - mae: 0.4149 - val_loss: 0.2482 - val_mae: 0.4165
# Epoch 238/500
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2443 - mae: 0.4132 - val_loss: 0.2460 - val_mae: 0.4146
# Epoch 239/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2420 - mae: 0.4113 - val_loss: 0.2442 - val_mae: 0.4138
# Epoch 240/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2399 - mae: 0.4102 - val_loss: 0.2416 - val_mae: 0.4110
# Epoch 241/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2379 - mae: 0.4073 - val_loss: 0.2392 - val_mae: 0.4081
# Epoch 242/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2358 - mae: 0.4063 - val_loss: 0.2376 - val_mae: 0.4079
# Epoch 243/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2334 - mae: 0.4040 - val_loss: 0.2351 - val_mae: 0.4053
# Epoch 244/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2316 - mae: 0.4016 - val_loss: 0.2327 - val_mae: 0.4025
# Epoch 245/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2299 - mae: 0.4019 - val_loss: 0.2319 - val_mae: 0.4038
# Epoch 246/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2270 - mae: 0.3981 - val_loss: 0.2282 - val_mae: 0.3977
# Epoch 247/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2252 - mae: 0.3956 - val_loss: 0.2265 - val_mae: 0.3975
# Epoch 248/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2227 - mae: 0.3946 - val_loss: 0.2246 - val_mae: 0.3964
# Epoch 249/500
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2206 - mae: 0.3932 - val_loss: 0.2223 - val_mae: 0.3937
# Epoch 250/500
# 10/10 [==============================] - 0s 16ms/step - loss: 0.2185 - mae: 0.3904 - val_loss: 0.2199 - val_mae: 0.3909
# Epoch 251/500
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2162 - mae: 0.3883 - val_loss: 0.2186 - val_mae: 0.3911
# Epoch 252/500
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2144 - mae: 0.3882 - val_loss: 0.2165 - val_mae: 0.3892
# Epoch 253/500
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2122 - mae: 0.3848 - val_loss: 0.2136 - val_mae: 0.3850
# Epoch 254/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2101 - mae: 0.3828 - val_loss: 0.2120 - val_mae: 0.3847
# Epoch 255/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2081 - mae: 0.3818 - val_loss: 0.2101 - val_mae: 0.3831
# Epoch 256/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2061 - mae: 0.3803 - val_loss: 0.2079 - val_mae: 0.3809
# Epoch 257/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2040 - mae: 0.3772 - val_loss: 0.2054 - val_mae: 0.3775
# Epoch 258/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2022 - mae: 0.3756 - val_loss: 0.2039 - val_mae: 0.3770
# Epoch 259/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2000 - mae: 0.3739 - val_loss: 0.2015 - val_mae: 0.3743
# Epoch 260/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1980 - mae: 0.3721 - val_loss: 0.1999 - val_mae: 0.3731
# Epoch 261/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1960 - mae: 0.3704 - val_loss: 0.1978 - val_mae: 0.3710
# Epoch 262/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1940 - mae: 0.3688 - val_loss: 0.1959 - val_mae: 0.3693
# Epoch 263/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1921 - mae: 0.3665 - val_loss: 0.1936 - val_mae: 0.3667
# Epoch 264/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1901 - mae: 0.3644 - val_loss: 0.1918 - val_mae: 0.3652
# Epoch 265/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1881 - mae: 0.3623 - val_loss: 0.1896 - val_mae: 0.3627
# Epoch 266/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1863 - mae: 0.3602 - val_loss: 0.1879 - val_mae: 0.3613
# Epoch 267/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1845 - mae: 0.3594 - val_loss: 0.1863 - val_mae: 0.3601
# Epoch 268/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1824 - mae: 0.3572 - val_loss: 0.1840 - val_mae: 0.3573
# Epoch 269/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1807 - mae: 0.3546 - val_loss: 0.1820 - val_mae: 0.3550
# Epoch 270/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1784 - mae: 0.3532 - val_loss: 0.1814 - val_mae: 0.3560
# Epoch 271/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1771 - mae: 0.3526 - val_loss: 0.1783 - val_mae: 0.3517
# Epoch 272/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1751 - mae: 0.3507 - val_loss: 0.1771 - val_mae: 0.3511
# Epoch 273/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1729 - mae: 0.3480 - val_loss: 0.1745 - val_mae: 0.3478
# Epoch 274/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1713 - mae: 0.3450 - val_loss: 0.1726 - val_mae: 0.3454
# Epoch 275/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1693 - mae: 0.3439 - val_loss: 0.1715 - val_mae: 0.3455
# Epoch 276/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1677 - mae: 0.3431 - val_loss: 0.1692 - val_mae: 0.3426
# Epoch 277/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1658 - mae: 0.3410 - val_loss: 0.1674 - val_mae: 0.3407
# Epoch 278/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1638 - mae: 0.3381 - val_loss: 0.1654 - val_mae: 0.3382
# Epoch 279/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1621 - mae: 0.3361 - val_loss: 0.1637 - val_mae: 0.3365
# Epoch 280/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1602 - mae: 0.3346 - val_loss: 0.1620 - val_mae: 0.3351
# Epoch 281/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1585 - mae: 0.3327 - val_loss: 0.1602 - val_mae: 0.3330
# Epoch 282/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1567 - mae: 0.3306 - val_loss: 0.1584 - val_mae: 0.3309
# Epoch 283/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1550 - mae: 0.3291 - val_loss: 0.1567 - val_mae: 0.3294
# Epoch 284/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1533 - mae: 0.3270 - val_loss: 0.1548 - val_mae: 0.3272
# Epoch 285/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1515 - mae: 0.3248 - val_loss: 0.1532 - val_mae: 0.3257
# Epoch 286/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1501 - mae: 0.3246 - val_loss: 0.1519 - val_mae: 0.3248
# Epoch 287/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1480 - mae: 0.3214 - val_loss: 0.1494 - val_mae: 0.3206
# Epoch 288/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1464 - mae: 0.3188 - val_loss: 0.1479 - val_mae: 0.3194
# Epoch 289/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1446 - mae: 0.3177 - val_loss: 0.1466 - val_mae: 0.3187
# Epoch 290/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1431 - mae: 0.3164 - val_loss: 0.1445 - val_mae: 0.3156
# Epoch 291/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1415 - mae: 0.3139 - val_loss: 0.1430 - val_mae: 0.3142
# Epoch 292/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1397 - mae: 0.3120 - val_loss: 0.1414 - val_mae: 0.3125
# Epoch 293/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1381 - mae: 0.3106 - val_loss: 0.1399 - val_mae: 0.3110
# Epoch 294/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1365 - mae: 0.3090 - val_loss: 0.1381 - val_mae: 0.3090
# Epoch 295/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1349 - mae: 0.3070 - val_loss: 0.1368 - val_mae: 0.3076
# Epoch 296/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1335 - mae: 0.3065 - val_loss: 0.1355 - val_mae: 0.3065
# Epoch 297/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1316 - mae: 0.3033 - val_loss: 0.1331 - val_mae: 0.3024
# Epoch 298/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1304 - mae: 0.3005 - val_loss: 0.1316 - val_mae: 0.3011
# Epoch 299/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1285 - mae: 0.2999 - val_loss: 0.1307 - val_mae: 0.3008
# Epoch 300/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1271 - mae: 0.2982 - val_loss: 0.1285 - val_mae: 0.2974
# Epoch 301/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1254 - mae: 0.2958 - val_loss: 0.1272 - val_mae: 0.2961
# Epoch 302/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1241 - mae: 0.2939 - val_loss: 0.1256 - val_mae: 0.2940
# Epoch 303/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1224 - mae: 0.2919 - val_loss: 0.1240 - val_mae: 0.2919
# Epoch 304/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1209 - mae: 0.2900 - val_loss: 0.1226 - val_mae: 0.2906
# Epoch 305/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1194 - mae: 0.2890 - val_loss: 0.1213 - val_mae: 0.2893
# Epoch 306/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1181 - mae: 0.2878 - val_loss: 0.1196 - val_mae: 0.2868
# Epoch 307/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1165 - mae: 0.2850 - val_loss: 0.1180 - val_mae: 0.2846
# Epoch 308/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1150 - mae: 0.2831 - val_loss: 0.1168 - val_mae: 0.2837
# Epoch 309/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1136 - mae: 0.2822 - val_loss: 0.1156 - val_mae: 0.2823
# Epoch 310/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1121 - mae: 0.2799 - val_loss: 0.1136 - val_mae: 0.2791
# Epoch 311/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1107 - mae: 0.2779 - val_loss: 0.1123 - val_mae: 0.2778
# Epoch 312/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1092 - mae: 0.2759 - val_loss: 0.1107 - val_mae: 0.2754
# Epoch 313/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1079 - mae: 0.2742 - val_loss: 0.1095 - val_mae: 0.2741
# Epoch 314/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1065 - mae: 0.2723 - val_loss: 0.1079 - val_mae: 0.2715
# Epoch 315/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1055 - mae: 0.2697 - val_loss: 0.1067 - val_mae: 0.2704
# Epoch 316/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1044 - mae: 0.2710 - val_loss: 0.1056 - val_mae: 0.2694
# Epoch 317/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1025 - mae: 0.2666 - val_loss: 0.1038 - val_mae: 0.2660
# Epoch 318/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1010 - mae: 0.2648 - val_loss: 0.1028 - val_mae: 0.2656
# Epoch 319/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0998 - mae: 0.2641 - val_loss: 0.1014 - val_mae: 0.2635
# Epoch 320/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0984 - mae: 0.2619 - val_loss: 0.0999 - val_mae: 0.2615
# Epoch 321/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0971 - mae: 0.2601 - val_loss: 0.0985 - val_mae: 0.2593
# Epoch 322/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0958 - mae: 0.2577 - val_loss: 0.0972 - val_mae: 0.2573
# Epoch 323/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0946 - mae: 0.2565 - val_loss: 0.0960 - val_mae: 0.2559
# Epoch 324/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0933 - mae: 0.2548 - val_loss: 0.0949 - val_mae: 0.2547
# Epoch 325/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0919 - mae: 0.2531 - val_loss: 0.0934 - val_mae: 0.2522
# Epoch 326/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0908 - mae: 0.2512 - val_loss: 0.0922 - val_mae: 0.2505
# Epoch 327/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0895 - mae: 0.2489 - val_loss: 0.0911 - val_mae: 0.2491
# Epoch 328/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0884 - mae: 0.2484 - val_loss: 0.0900 - val_mae: 0.2477
# Epoch 329/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0871 - mae: 0.2460 - val_loss: 0.0886 - val_mae: 0.2451
# Epoch 330/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0861 - mae: 0.2434 - val_loss: 0.0874 - val_mae: 0.2436
# Epoch 331/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0847 - mae: 0.2427 - val_loss: 0.0867 - val_mae: 0.2433
# Epoch 332/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0840 - mae: 0.2425 - val_loss: 0.0851 - val_mae: 0.2405
# Epoch 333/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0825 - mae: 0.2385 - val_loss: 0.0839 - val_mae: 0.2384
# Epoch 334/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0815 - mae: 0.2388 - val_loss: 0.0832 - val_mae: 0.2381
# Epoch 335/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0803 - mae: 0.2354 - val_loss: 0.0816 - val_mae: 0.2348
# Epoch 336/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0794 - mae: 0.2353 - val_loss: 0.0806 - val_mae: 0.2339
# Epoch 337/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0781 - mae: 0.2320 - val_loss: 0.0794 - val_mae: 0.2314
# Epoch 338/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0770 - mae: 0.2312 - val_loss: 0.0785 - val_mae: 0.2308
# Epoch 339/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0758 - mae: 0.2297 - val_loss: 0.0773 - val_mae: 0.2287
# Epoch 340/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0748 - mae: 0.2269 - val_loss: 0.0761 - val_mae: 0.2264
# Epoch 341/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0737 - mae: 0.2258 - val_loss: 0.0752 - val_mae: 0.2253
# Epoch 342/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0726 - mae: 0.2245 - val_loss: 0.0744 - val_mae: 0.2243
# Epoch 343/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0717 - mae: 0.2230 - val_loss: 0.0730 - val_mae: 0.2217
# Epoch 344/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0706 - mae: 0.2209 - val_loss: 0.0724 - val_mae: 0.2212
# Epoch 345/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0696 - mae: 0.2199 - val_loss: 0.0710 - val_mae: 0.2186
# Epoch 346/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0686 - mae: 0.2173 - val_loss: 0.0700 - val_mae: 0.2170
# Epoch 347/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0676 - mae: 0.2164 - val_loss: 0.0693 - val_mae: 0.2162
# Epoch 348/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0669 - mae: 0.2147 - val_loss: 0.0680 - val_mae: 0.2132
# Epoch 349/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0657 - mae: 0.2139 - val_loss: 0.0675 - val_mae: 0.2133
# Epoch 350/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0649 - mae: 0.2118 - val_loss: 0.0661 - val_mae: 0.2103
# Epoch 351/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0637 - mae: 0.2097 - val_loss: 0.0653 - val_mae: 0.2091
# Epoch 352/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0629 - mae: 0.2088 - val_loss: 0.0642 - val_mae: 0.2070
# Epoch 353/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0619 - mae: 0.2061 - val_loss: 0.0633 - val_mae: 0.2057
# Epoch 354/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0610 - mae: 0.2049 - val_loss: 0.0625 - val_mae: 0.2045
# Epoch 355/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0606 - mae: 0.2062 - val_loss: 0.0616 - val_mae: 0.2028
# Epoch 356/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0593 - mae: 0.2009 - val_loss: 0.0605 - val_mae: 0.2001
# Epoch 357/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0583 - mae: 0.2004 - val_loss: 0.0600 - val_mae: 0.2002
# Epoch 358/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0575 - mae: 0.1999 - val_loss: 0.0590 - val_mae: 0.1982
# Epoch 359/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0566 - mae: 0.1970 - val_loss: 0.0579 - val_mae: 0.1956
# Epoch 360/500
# ...
# Epoch 381/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0404 - mae: 0.1662 - val_loss: 0.0417 - val_mae: 0.1645
# Epoch 382/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0397 - mae: 0.1650 - val_loss: 0.0410 - val_mae: 0.1630
# Epoch 383/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0392 - mae: 0.1644 - val_loss: 0.0404 - val_mae: 0.1615
# Epoch 384/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0386 - mae: 0.1618 - val_loss: 0.0397 - val_mae: 0.1600
# Epoch 385/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0379 - mae: 0.1615 - val_loss: 0.0393 - val_mae: 0.1597
# Epoch 386/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0373 - mae: 0.1602 - val_loss: 0.0385 - val_mae: 0.1573
# Epoch 387/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0369 - mae: 0.1579 - val_loss: 0.0380 - val_mae: 0.1563
# Epoch 388/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0365 - mae: 0.1593 - val_loss: 0.0375 - val_mae: 0.1554
# Epoch 389/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0360 - mae: 0.1561 - val_loss: 0.0369 - val_mae: 0.1540
# Epoch 390/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0352 - mae: 0.1559 - val_loss: 0.0363 - val_mae: 0.1528
# Epoch 391/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0347 - mae: 0.1536 - val_loss: 0.0357 - val_mae: 0.1512
# Epoch 392/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0342 - mae: 0.1539 - val_loss: 0.0353 - val_mae: 0.1505
# Epoch 393/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0336 - mae: 0.1512 - val_loss: 0.0347 - val_mae: 0.1487
# Epoch 394/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0330 - mae: 0.1501 - val_loss: 0.0343 - val_mae: 0.1480
# Epoch 395/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - mae: 0.1491 - val_loss: 0.0337 - val_mae: 0.1465
# Epoch 396/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0320 - mae: 0.1481 - val_loss: 0.0334 - val_mae: 0.1463
# Epoch 397/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0315 - mae: 0.1472 - val_loss: 0.0326 - val_mae: 0.1436
# Epoch 398/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0313 - mae: 0.1455 - val_loss: 0.0323 - val_mae: 0.1435
# Epoch 399/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0308 - mae: 0.1448 - val_loss: 0.0319 - val_mae: 0.1425
# Epoch 400/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0301 - mae: 0.1437 - val_loss: 0.0312 - val_mae: 0.1404
# Epoch 401/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0296 - mae: 0.1421 - val_loss: 0.0308 - val_mae: 0.1397
# Epoch 402/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0291 - mae: 0.1413 - val_loss: 0.0304 - val_mae: 0.1387
# Epoch 403/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0288 - mae: 0.1401 - val_loss: 0.0299 - val_mae: 0.1375
# Epoch 404/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0284 - mae: 0.1389 - val_loss: 0.0295 - val_mae: 0.1363
# Epoch 405/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0279 - mae: 0.1376 - val_loss: 0.0290 - val_mae: 0.1353
# Epoch 406/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0275 - mae: 0.1372 - val_loss: 0.0286 - val_mae: 0.1342
# Epoch 407/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0270 - mae: 0.1355 - val_loss: 0.0281 - val_mae: 0.1327
# Epoch 408/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0266 - mae: 0.1343 - val_loss: 0.0281 - val_mae: 0.1332
# Epoch 409/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0264 - mae: 0.1343 - val_loss: 0.0273 - val_mae: 0.1309
# Epoch 410/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0258 - mae: 0.1328 - val_loss: 0.0270 - val_mae: 0.1300
# Epoch 411/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0254 - mae: 0.1310 - val_loss: 0.0265 - val_mae: 0.1286
# Epoch 412/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0250 - mae: 0.1304 - val_loss: 0.0262 - val_mae: 0.1281
# Epoch 413/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0247 - mae: 0.1295 - val_loss: 0.0257 - val_mae: 0.1267
# Epoch 414/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0243 - mae: 0.1289 - val_loss: 0.0253 - val_mae: 0.1256
# Epoch 415/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0240 - mae: 0.1271 - val_loss: 0.0250 - val_mae: 0.1248
# Epoch 416/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0237 - mae: 0.1273 - val_loss: 0.0246 - val_mae: 0.1238
# Epoch 417/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0233 - mae: 0.1253 - val_loss: 0.0243 - val_mae: 0.1229
# Epoch 418/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0230 - mae: 0.1250 - val_loss: 0.0239 - val_mae: 0.1218
# Epoch 419/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0226 - mae: 0.1233 - val_loss: 0.0237 - val_mae: 0.1213
# Epoch 420/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0224 - mae: 0.1238 - val_loss: 0.0232 - val_mae: 0.1200
# Epoch 421/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0220 - mae: 0.1223 - val_loss: 0.0231 - val_mae: 0.1200
# Epoch 422/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0216 - mae: 0.1212 - val_loss: 0.0226 - val_mae: 0.1183
# Epoch 423/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0213 - mae: 0.1199 - val_loss: 0.0224 - val_mae: 0.1180
# Epoch 424/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0210 - mae: 0.1196 - val_loss: 0.0219 - val_mae: 0.1165
# Epoch 425/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0207 - mae: 0.1183 - val_loss: 0.0217 - val_mae: 0.1162
# Epoch 426/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0204 - mae: 0.1174 - val_loss: 0.0214 - val_mae: 0.1153
# Epoch 427/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0201 - mae: 0.1166 - val_loss: 0.0211 - val_mae: 0.1143
# Epoch 428/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0198 - mae: 0.1159 - val_loss: 0.0208 - val_mae: 0.1137
# Epoch 429/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0195 - mae: 0.1149 - val_loss: 0.0205 - val_mae: 0.1125
# Epoch 430/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0193 - mae: 0.1138 - val_loss: 0.0203 - val_mae: 0.1123
# Epoch 431/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0191 - mae: 0.1138 - val_loss: 0.0199 - val_mae: 0.1110
# Epoch 432/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0192 - mae: 0.1133 - val_loss: 0.0199 - val_mae: 0.1114
# Epoch 433/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0185 - mae: 0.1120 - val_loss: 0.0195 - val_mae: 0.1098
# Epoch 434/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0183 - mae: 0.1106 - val_loss: 0.0192 - val_mae: 0.1090
# Epoch 435/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0181 - mae: 0.1105 - val_loss: 0.0190 - val_mae: 0.1087
# Epoch 436/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0178 - mae: 0.1092 - val_loss: 0.0187 - val_mae: 0.1076
# Epoch 437/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0176 - mae: 0.1091 - val_loss: 0.0185 - val_mae: 0.1068
# Epoch 438/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0175 - mae: 0.1079 - val_loss: 0.0184 - val_mae: 0.1070
# Epoch 439/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0172 - mae: 0.1080 - val_loss: 0.0181 - val_mae: 0.1058
# Epoch 440/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0171 - mae: 0.1066 - val_loss: 0.0178 - val_mae: 0.1051
# Epoch 441/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0170 - mae: 0.1072 - val_loss: 0.0176 - val_mae: 0.1042
# Epoch 442/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0166 - mae: 0.1053 - val_loss: 0.0175 - val_mae: 0.1043
# Epoch 443/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0165 - mae: 0.1048 - val_loss: 0.0171 - val_mae: 0.1029
# Epoch 444/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0161 - mae: 0.1039 - val_loss: 0.0170 - val_mae: 0.1030
# Epoch 445/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0159 - mae: 0.1029 - val_loss: 0.0167 - val_mae: 0.1017
# Epoch 446/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0157 - mae: 0.1022 - val_loss: 0.0166 - val_mae: 0.1014
# Epoch 447/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0155 - mae: 0.1015 - val_loss: 0.0164 - val_mae: 0.1009
# Epoch 448/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0154 - mae: 0.1014 - val_loss: 0.0162 - val_mae: 0.1000
# Epoch 449/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0152 - mae: 0.1003 - val_loss: 0.0161 - val_mae: 0.1000
# Epoch 450/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0152 - mae: 0.1011 - val_loss: 0.0158 - val_mae: 0.0986
# Epoch 451/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0150 - mae: 0.0996 - val_loss: 0.0160 - val_mae: 0.1002
# Epoch 452/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0147 - mae: 0.0992 - val_loss: 0.0154 - val_mae: 0.0977
# Epoch 453/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - mae: 0.0981 - val_loss: 0.0154 - val_mae: 0.0979
# Epoch 454/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - mae: 0.0978 - val_loss: 0.0151 - val_mae: 0.0968
# Epoch 455/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - mae: 0.0970 - val_loss: 0.0151 - val_mae: 0.0969
# Epoch 456/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - mae: 0.0968 - val_loss: 0.0149 - val_mae: 0.0965
# Epoch 457/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0140 - mae: 0.0966 - val_loss: 0.0147 - val_mae: 0.0954
# Epoch 458/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0138 - mae: 0.0954 - val_loss: 0.0146 - val_mae: 0.0953
# Epoch 459/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0136 - mae: 0.0949 - val_loss: 0.0144 - val_mae: 0.0948
# Epoch 460/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0135 - mae: 0.0944 - val_loss: 0.0144 - val_mae: 0.0948
# Epoch 461/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0134 - mae: 0.0944 - val_loss: 0.0141 - val_mae: 0.0939
# Epoch 462/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0133 - mae: 0.0942 - val_loss: 0.0140 - val_mae: 0.0932
# Epoch 463/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0132 - mae: 0.0932 - val_loss: 0.0140 - val_mae: 0.0938
# Epoch 464/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0131 - mae: 0.0931 - val_loss: 0.0138 - val_mae: 0.0929
# Epoch 465/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0129 - mae: 0.0922 - val_loss: 0.0136 - val_mae: 0.0921
# Epoch 466/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0127 - mae: 0.0916 - val_loss: 0.0135 - val_mae: 0.0920
# Epoch 467/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0126 - mae: 0.0914 - val_loss: 0.0133 - val_mae: 0.0914
# Epoch 468/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0127 - mae: 0.0913 - val_loss: 0.0136 - val_mae: 0.0929
# Epoch 469/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0128 - mae: 0.0919 - val_loss: 0.0131 - val_mae: 0.0901
# Epoch 470/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0124 - mae: 0.0900 - val_loss: 0.0133 - val_mae: 0.0917
# Epoch 471/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0122 - mae: 0.0898 - val_loss: 0.0129 - val_mae: 0.0898
# Epoch 472/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0894 - val_loss: 0.0128 - val_mae: 0.0898
# Epoch 473/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0120 - mae: 0.0887 - val_loss: 0.0127 - val_mae: 0.0893
# Epoch 474/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0119 - mae: 0.0885 - val_loss: 0.0128 - val_mae: 0.0903
# Epoch 475/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0119 - mae: 0.0889 - val_loss: 0.0125 - val_mae: 0.0884
# Epoch 476/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0117 - mae: 0.0879 - val_loss: 0.0124 - val_mae: 0.0884
# Epoch 477/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0116 - mae: 0.0874 - val_loss: 0.0123 - val_mae: 0.0882
# Epoch 478/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0116 - mae: 0.0871 - val_loss: 0.0123 - val_mae: 0.0884
# Epoch 479/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0115 - mae: 0.0867 - val_loss: 0.0121 - val_mae: 0.0875
# Epoch 480/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0114 - mae: 0.0864 - val_loss: 0.0121 - val_mae: 0.0873
# Epoch 481/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0114 - mae: 0.0865 - val_loss: 0.0121 - val_mae: 0.0878
# Epoch 482/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0113 - mae: 0.0859 - val_loss: 0.0119 - val_mae: 0.0863
# Epoch 483/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0112 - mae: 0.0860 - val_loss: 0.0118 - val_mae: 0.0862
# Epoch 484/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0111 - mae: 0.0855 - val_loss: 0.0118 - val_mae: 0.0865
# Epoch 485/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0111 - mae: 0.0852 - val_loss: 0.0117 - val_mae: 0.0861
# Epoch 486/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0110 - mae: 0.0849 - val_loss: 0.0119 - val_mae: 0.0876
# Epoch 487/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0110 - mae: 0.0847 - val_loss: 0.0115 - val_mae: 0.0855
# Epoch 488/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0108 - mae: 0.0844 - val_loss: 0.0114 - val_mae: 0.0850
# Epoch 489/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0108 - mae: 0.0838 - val_loss: 0.0114 - val_mae: 0.0854
# Epoch 490/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0107 - mae: 0.0835 - val_loss: 0.0113 - val_mae: 0.0845
# Epoch 491/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0106 - mae: 0.0833 - val_loss: 0.0113 - val_mae: 0.0852
# Epoch 492/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0106 - mae: 0.0831 - val_loss: 0.0112 - val_mae: 0.0845
# Epoch 493/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0106 - mae: 0.0831 - val_loss: 0.0111 - val_mae: 0.0840
# Epoch 494/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0828 - val_loss: 0.0111 - val_mae: 0.0845
# Epoch 495/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0105 - mae: 0.0830 - val_loss: 0.0110 - val_mae: 0.0834
# Epoch 496/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0104 - mae: 0.0825 - val_loss: 0.0112 - val_mae: 0.0849
# Epoch 497/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0105 - mae: 0.0829 - val_loss: 0.0110 - val_mae: 0.0838
# Epoch 498/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - mae: 0.0821 - val_loss: 0.0109 - val_mae: 0.0837
# Epoch 499/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - mae: 0.0820 - val_loss: 0.0110 - val_mae: 0.0841
# Epoch 500/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0828 - val_loss: 0.0108 - val_mae: 0.0826

# %%
# Save the model to disk
model.save(MODEL_TF)
# Out:
# INFO:tensorflow:Assets written to: models/model/assets
# INFO:tensorflow:Assets written to: models/model/assets

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

# Exclude the first few epochs so the graph is easier to read
SKIP = 20

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history.history['mae']
val_mae = history.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predicted')
plt.legend()
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0122 - mae: 0.0885

# %%
# Convert the model to the TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_TF)
model_no_quant_tflite = converter.convert()

# Save the model to disk
open(MODEL_NO_QUANT_TFLITE, "wb").write(model_no_quant_tflite)

# Convert the model to the TensorFlow Lite format with quantization
def representative_dataset():
  for i in range(500):
    yield([x_train[i].reshape(1, 1)])
# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce integer only quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(MODEL_TFLITE, "wb").write(model_tflite)
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 3256

# %%
def predict_tflite(tflite_model, x_test):
  # Prepare the test data
  x_test_ = x_test.copy()
  x_test_ = x_test_.reshape((x_test.size, 1))
  x_test_ = x_test_.astype(np.float32)

  # Initialize the TFLite interpreter
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # If required, quantize the input layer (from float to integer)
  input_scale, input_zero_point = input_details["quantization"]
  if (input_scale, input_zero_point) != (0.0, 0):
    x_test_ = x_test_ / input_scale + input_zero_point
    x_test_ = x_test_.astype(input_details["dtype"])
  
  # Invoke the interpreter
  y_pred = np.empty(x_test_.size, dtype=output_details["dtype"])
  for i in range(len(x_test_)):
    interpreter.set_tensor(input_details["index"], [x_test_[i]])
    interpreter.invoke()
    y_pred[i] = interpreter.get_tensor(output_details["index"])[0]
  
  # If required, dequantized the output layer (from integer to float)
  output_scale, output_zero_point = output_details["quantization"]
  if (output_scale, output_zero_point) != (0.0, 0):
    y_pred = y_pred.astype(np.float32)
    y_pred = (y_pred - output_zero_point) * output_scale

  return y_pred

def evaluate_tflite(tflite_model, x_test, y_true):
  global model
  y_pred = predict_tflite(tflite_model, x_test)
  loss_function = tf.keras.losses.get(model.loss)
  loss = loss_function(y_true, y_pred).numpy()
  return loss

# %%
# Calculate predictions
y_test_pred_tf = model.predict(x_test)
y_test_pred_no_quant_tflite = predict_tflite(model_no_quant_tflite, x_test)
y_test_pred_tflite = predict_tflite(model_tflite, x_test)

# Compare predictions
plt.clf()
plt.title('Comparison of various models against actual values')
plt.plot(x_test, y_test, 'bo', label='Actual values')
plt.plot(x_test, y_test_pred_tf, 'ro', label='TF predictions')
plt.plot(x_test, y_test_pred_no_quant_tflite, 'bx', label='TFLite predictions')
plt.plot(x_test, y_test_pred_tflite, 'gx', label='TFLite quantized predictions')
plt.legend()
plt.show()

# %%
# Calculate loss
loss_tf, _ = model.evaluate(x_test, y_test, verbose=0)
loss_no_quant_tflite = evaluate_tflite(model_no_quant_tflite, x_test, y_test)
loss_tflite = evaluate_tflite(model_tflite, x_test, y_test)

# Compare loss
df = pd.DataFrame.from_records(
    [["TensorFlow", loss_tf],
     ["TensorFlow Lite", loss_no_quant_tflite],
     ["TensorFlow Lite Quantized", loss_tflite]],
     columns = ["Model", "Loss/MSE"], index="Model").round(4)
df
# Out:
#                            Loss/MSE
# Model
# TensorFlow                   0.0122
# TensorFlow Lite              0.0122
# TensorFlow Lite Quantized   10.0491

# %%
# Calculate size
size_tf = os.path.getsize(MODEL_TF)
size_no_quant_tflite = os.path.getsize(MODEL_NO_QUANT_TFLITE)
size_tflite = os.path.getsize(MODEL_TFLITE)

# Compare size
pd.DataFrame.from_records(
    [["TensorFlow", f"{size_tf} bytes", ""],
     ["TensorFlow Lite", f"{size_no_quant_tflite} bytes ", f"(reduced by {size_tf - size_no_quant_tflite} bytes)"],
     ["TensorFlow Lite Quantized", f"{size_tflite} bytes", f"(reduced by {size_no_quant_tflite - size_tflite} bytes)"]],
     columns = ["Model", "Size", ""], index="Model")
# Out:
#                                   Size
# Model
# TensorFlow                  4096 bytes
# TensorFlow Lite            4432 bytes   (reduced by -336 bytes)
# TensorFlow Lite Quantized   3256 bytes  (reduced by 1176 bytes)

# %%
# demonstrate prediction
from numpy import array
x_input = array([200])
print (x_input.shape)
x_input = x_input.reshape((1, 1, 1))
print (x_input.shape)
yhat = model.predict(x_input, verbose=0)
print(yhat)
# Out:
# (1,)
# (1, 1, 1)
# [[2004.8832]]
